# %%
pip install torch torchvision torchaudio
# Out:
# ...
#   Using cached torch-2.12.1-cp313-cp313-macosx_14_0_arm64.whl.metadata (31 kB)
# ...
#   Using cached torchvision-0.27.1-cp313-cp313-macosx_14_0_arm64.whl.metadata (5.5 kB)
# ...
#   Using cached torchaudio-2.11.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (6.9 kB)
# ...
# Using cached torch-2.12.1-cp313-cp313-macosx_14_0_arm64.whl (88.0 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 2.9 MB/s  0:00:00m0:00:010m
# Using cached torchvision-0.27.1-cp313-cp313-macosx_14_0_arm64.whl (1.9 MB)
# Using cached torchaudio-2.11.0-cp313-cp313-macosx_12_0_arm64.whl (679 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.7 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 3.3 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 3.3 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 2.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 3.5 MB/s  0:00:01 eta 0:00:01
# ...
